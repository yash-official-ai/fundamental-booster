# %% [markdown]
# # ⭐ FUNDAMENTAL BOOSTER

# %%
#personal data collector program
print("\n welcome to the interactive personal data collector!")

#taking inputs

name=input("please enter your name:")
age=int(input("please enter your age:"))
height=float(input("please enter your height in meters:"))
fav_number=int(input("please enter your favourite number"))

print("\nThankyou! Here is the information we collected\n")

print(type(name))
print(id(name))
print(type(age))
print(id(age))
print(type(height))
print(id(height))
print(type(fav_number))
print(id(fav_number))

current_year=2026
birth_year=2008
print(f"\nyour birth year is approximately:{birth_year}(based on your age of{age}")


print("\nThank you for using the personal data collector. Goodbye!")
# Out:
#  welcome to the interactive personal data collector!
# please enter your name: yash
# please enter your age: 17
# please enter your height in meters: 1.08
# please enter your favourite number 25
# Thankyou! Here is the information we collected
#
# <class 'str'>
# 1664064133936
# <class 'int'>
# 140725117105576
# <class 'float'>
# 1664062515024
# <class 'int'>
# 140725117105832
#
# your birth year is approximately:2008(based on your age of17
#
# Thank you for using the personal data collector. Goodbye!
